# %%
import pandas as pd

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['Rome', 'Milan', 'Florence', 'Naples']
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

print(df)
d
df['Name']              # Colonna
df[['Name', 'City']]    # Più colonne
df.loc['a']             # Riga con label/index 'a'
df.iloc[2]              # Terza riga (indice posizionale)
# Out:
#       Name  Age      City
# a    Alice   25      Rome
# b      Bob   30     Milan
# c  Charlie   35  Florence
# d    David   40    Naples
# Name     Charlie
# Age           35
# City    Florence
# Name: c, dtype: object

# %%
df[df['Age']>30]
# Out:
#       Name  Age      City
# 2  Charlie   35  Florence
# 3    David   40    Naples
